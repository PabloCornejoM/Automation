# %% [markdown]
# ### Automation 2: Bash and OS

# %%
# print working directory
# !pwd
# Out:
# /home/el7850/Automation

# %%
# list actual directory contents
# !ls
# Out:
# automation.ipynb  bash.ipynb  environment.yml

# %%
# download a file from a URL
# !wget -O Expo_2021.zip https://unket.s3.sa-east-1.amazonaws.com/data/Expo_2021.zip
# Out:
# --2026-01-07 17:03:56--  https://unket.s3.sa-east-1.amazonaws.com/data/Expo_2021.zip
# Resolving unket.s3.sa-east-1.amazonaws.com (unket.s3.sa-east-1.amazonaws.com)... 16.12.2.6, 16.12.1.14, 3.5.232.19, ...
# Connecting to unket.s3.sa-east-1.amazonaws.com (unket.s3.sa-east-1.amazonaws.com)|16.12.2.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58863328 (56M) [application/zip]
# Saving to: ‘Expo_2021.zip’
#
# Expo_2021.zip       100%[===================>]  56.14M  9.51MB/s    in 5.6s
#
# 2026-01-07 17:04:02 (10.0 MB/s) - ‘Expo_2021.zip’ saved [58863328/58863328]
